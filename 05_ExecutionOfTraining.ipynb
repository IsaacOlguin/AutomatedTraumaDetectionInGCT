# %%
# %load_ext autoreload
# %autoreload 2

GLB_INSTALL_DEPENDENCIES = True
GLB_USE_DRIVE_ACCOUNT = True

# %%
if GLB_INSTALL_DEPENDENCIES:
    # !pip install transformers
    # !pip install torch
    # !pip install openpyxl

# %%
if GLB_USE_DRIVE_ACCOUNT:
  from google.colab import drive
  drive.mount('/content/drive')
  # %cd /content/drive/MyDrive/"Colab Notebooks"
  username = "IsaacOlguin"
  repository =  "AutomatedTraumaDetectionInGCT"
  # %cd {repository}
  # %pwd

# %%
# %reload_ext autoreload
if GLB_USE_DRIVE_ACCOUNT:
  # !python /content/drive/MyDrive/"Colab Notebooks"/AutomatedTraumaDetectionInGCT/src/multilabel_classification.py
else:
  # !python src/multilabel_classification.py
